# %% [markdown]
# ## Import packages

# %%
import os
import pandas as pd
import numpy as np
import requests
import json
import time
from datetime import datetime, timedelta

from shroomdk import ShroomDK

# %% [markdown]
# ## API Set-up

# %%
# Get API_KEY from file

def get_file_contents(filename):
    """ Given a filename,
        return the contents of that file
    """
    try:
        with open(filename, 'r', encoding="utf-8-sig") as f:
            # It's assumed our file contains a single line,
            # with our API key
            return f.read().strip()
    except FileNotFoundError:
        print("'%s' file not found" % filename)

# %%
# Get all results from query with pagination

def querying_pagination(query_string):
    sdk = ShroomDK(API_KEY)
    
    # Query results page by page and saves the results in a list
    # If nothing is returned then just stop the loop and start adding the data to the dataframe
    result_list = []
    for i in range(1,11): # max is a million rows @ 100k per page
        data=sdk.query(query_string,page_size=100000,page_number=i)
        if data.run_stats.record_count == 0:  
            break
        else:
            result_list.append(data.records)
        
    # Loops through the returned results and adds into a pandas dataframe
    result_df=pd.DataFrame()
    for idx, each_list in enumerate(result_list):
        if idx == 0:
            result_df=pd.json_normalize(each_list)
        else:
            result_df=pd.concat([result_df, pd.json_normalize(each_list)])

    return result_df

# %%
# Call query, save csv and return the df of a query
def query_to_df(sql_query):
    df = querying_pagination(sql_query)
    df.to_csv(f'data/{sql_query}csv', index=False) 
    return df

# %%
API_KEY = get_file_contents('/home/agustin/DS/Projects/NearSocialSegmentApp/keys/apikey.txt')

# Initialize `ShroomDK` with my API Key
sdk = ShroomDK(API_KEY)

# %% [markdown]
# ## SQL Queries with SDK API

# %%
# Near Social auths
auths_raw_sql = open('/home/agustin/DS/Projects/NearSocialSegmentApp/data/queries/sn_auths.txt').read()

auths_raw_df = querying_pagination(auths_raw_sql)

auths_raw_df.to_csv('/home/agustin/DS/Projects/NearSocialSegmentApp/data/csv/auths_raw_df.csv', index=False)

# %%
# Near Social DeFi
defi_raw_sql = open('/home/agustin/DS/Projects/NearSocialSegmentApp/data/queries/sn_defi_activity.txt').read()

defi_raw_df = querying_pagination(defi_raw_sql)

defi_raw_df.to_csv('/home/agustin/DS/Projects/NearSocialSegmentApp/data/csv/defi_raw_df.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# UserError                                 Traceback (most recent call last)
# Cell In[94], line 4
#       1 # Near Social DeFi
#       2 defi_raw_sql = open('/home/agustin/DS/Projects/NearSocialSegmentApp/data/queries/sn_defi_activity.txt').read()
# ----> 4 defi_raw_df = querying_pagination(defi_raw_sql)
#       6 defi_raw_df.to_csv('/home/agustin/DS/Projects/NearSocialSegmentApp/data/csv/defi_raw_df.csv', index=False)
#
# Cell In[22], line 10, in querying_pagination(query_string)
#       8 result_list = []
#       9 for i in range(1,11): # max is a million rows @ 100k per page
# ---> 10     data=sdk.query(query_string,page_size=100000,page_number=i)
#      11     if data.run_stats.record_count == 0:
#      12         break
#
# File ~/anaconda3/lib/python3.9/site-packages/shroomdk/shroomdk.py:27, in ShroomDK.query(self, sql, ttl_minutes, cached, timeout_minutes, retry_interval_seconds, page_size, page_number)
#      15 def query(
#      16     self,
#      17     sql,
#    (...)
#      23     page_number=1,
#      24 ):
#      25     query_integration = QueryIntegration(self.api)
# ---> 27     return query_integration.run(
#      28         Query(
#      29             sql=sql,
#      30             ttl_minutes=ttl_minutes,
#      31             timeout_minutes=timeout_minutes,
#      32             retry_interval_seconds=retry_interval_seconds,
#      33             page_size=page_size,
#      34             page_number=page_number,
#      35             cached=cached,
#      36             sdk_package=SDK_PACKAGE,
#      37             sdk_version=SDK_VERSION,
#      38         )
#      39     )
#
# File ~/anaconda3/lib/python3.9/site-packages/shroomdk/integrations/query_integration/query_integration.py:56, in QueryIntegration.run(self, query)
#      53 if not query_run:
#      54     raise SDKError("expected `created_query.data` from server but got `None`")
# ---> 56 query_results = self._get_query_results(
#      57     query_run.token,
#      58     page_number=query.page_number,
#      59     page_size=query.page_size,
#      60     timeout_minutes=query.timeout_minutes if query.timeout_minutes else 20,
#      61     retry_interval_seconds=query.retry_interval_seconds
#      62     if query.retry_interval_seconds
#      63     else 1,
#      64 )
#      66 return QueryResultSetBuilder(query_results).build()
#
# File ~/anaconda3/lib/python3.9/site-packages/shroomdk/integrations/query_integration/query_integration.py:130, in QueryIntegration._get_query_results(self, query_run_id, page_number, page_size, attempts, timeout_minutes, retry_interval_seconds)
#     120     elapsed_seconds = get_elapsed_linear_seconds(
#     121         SleepConfig(
#     122             attempts=attempts,
#    (...)
#     125         )
#     126     )
#     128     raise QueryRunTimeoutError(elapsed_seconds)
# --> 130 return self._get_query_results(
#     131     query_run_id,
#     132     page_number,
#     133     page_size,
#     134     attempts + 1,
#     135     timeout_minutes,
#     136     retry_interval_seconds,
#     137 )
#
# File ~/anaconda3/lib/python3.9/site-packages/shroomdk/integrations/query_integration/query_integration.py:94, in QueryIntegration._get_query_results(self, query_run_id, page_number, page_size, attempts, timeout_minutes, retry_interval_seconds)
#      92     error_msg = query_run.error_msg
#      93 if status_code >= 400 and status_code <= 499:
# ---> 94     raise UserError(status_code, error_msg)
#      95 elif status_code >= 500:
#      96     raise ServerError(status_code, error_msg)
#
# UserError: user error occured with status code: 400, msg: SQL compilation error: Failure during expansion of view 'FACT_ACTIONS_EVENTS_ADDKEY': SQL compilation error: Schema 'NEAR.SILVER' does not exist or not authorized.

# %%
# Near Social users
users_raw_sql = open('/home/agustin/DS/Projects/NearSocialSegmentApp/data/queries/sn_users.txt').read()

users_raw_df = querying_pagination(users_raw_sql)

users_raw_df.to_csv('/home/agustin/DS/Projects/NearSocialSegmentApp/data/csv/users_raw_df.csv', index=False)

# %%
auths_raw_df
# Out:
#                                                    user first_social_sign  \
# 0     0d385e3d331d4112a761ec89f80d25cb2fc0eef0ca4b67...        2023-03-14
# 1                              jumpgroupfoundation.near        2023-03-14
# 2                                         sunsheng.near        2023-03-14
# 3                                    oliveragustin.near        2023-03-14
# 4                                      meta-artfun.near        2023-03-14
# ...                                                 ...               ...
# 8070                                   rucommunity.near        2022-02-18
# 8071                                       kotleta.near        2022-02-17
# 8072                                          vlad.near        2022-02-17
# 8073                                   aliaksandrh.near        2022-02-17
# 8074                                           mob.near        2022-02-16
#
#      wallet_creation  age_days age_category human_readable
# 0         2023-02-21        21   0-3 MONTHS             NO
# 1         2022-10-06       159   3-6 MONTHS            YES
# 2         2021-05-14       669    1-2 YEARS            YES
# 3         2023-03-02        12   0-3 MONTHS            YES
# 4         2022-08-28       198  6-12 MONTHS            YES
# ...              ...       ...          ...            ...
# 8070      2021-04-06       318  6-12 MONTHS            YES
# 8071      2021-06-01       261  6-12 MONTHS            YES
# 8072      2020-07-31       566    1-2 YEARS            YES
# 8073      2020-09-13       522    1-2 YEARS            YES
# 8074      2020-11-09       464    1-2 YEARS            YES
#
# [8075 rows x 6 columns]

# %%
defi_raw_df
# Out:
#                                                    user  \
# 0                                           tyty14.near
# 1                                        pixel8llc.near
# 2                                           ilerik.near
# 3                                         sonudb54.near
# 4                                             pam1.near
# ...                                                 ...
# 8070                                    hackerluck.near
# 8071  a1f5411e1497eacb7a394499bc857f6d27da86b53540b6...
# 8072                                        nallin.near
# 8073                                   ebonybarker.near
# 8074                                         inlog.near
#
#             first_social_sign  number_of_swaps swaps_category  \
# 0     2023-03-05 09:01:25.754                1     1-10 SWAPS
# 1     2022-10-06 16:50:38.990                5     1-10 SWAPS
# 2     2022-05-23 05:05:25.281                0       NO SWAPS
# 3     2023-03-05 14:14:22.355                3     1-10 SWAPS
# 4     2023-03-06 08:41:44.904                0       NO SWAPS
# ...                       ...              ...            ...
# 8070  2023-03-05 01:56:53.373                0       NO SWAPS
# 8071  2023-02-23 16:23:50.793               10     1-10 SWAPS
# 8072  2022-12-08 18:28:26.881                0       NO SWAPS
# 8073  2023-03-11 06:03:08.105                3     1-10 SWAPS
# 8074  2022-10-05 23:55:16.884                0       NO SWAPS
#
#      swapped_before_social  number_stake_actions  current_stake_raw  \
# 0                      YES                     1           0.128619
# 1                      YES                     8          -4.743708
# 2            NEVER SWAPPED                     7           0.492973
# 3                      YES                     0                NaN
# 4            NEVER SWAPPED                     0                NaN
# ...                    ...                   ...                ...
# 8070         NEVER SWAPPED                     0                NaN
# 8071                   YES                     0                NaN
# 8072         NEVER SWAPPED                     0                NaN
# 8073                   YES                     0                NaN
# 8074         NEVER SWAPPED                     0                NaN
#
#       current_stake stake_category staked_before_social     defi_category
# 0          0.128619   0-100 STAKED                  YES       DEFI MASTER
# 1          0.000000       NO STAKE                  YES       DEFI MASTER
# 2          0.492973   0-100 STAKED                  YES       ONLY STAKED
# 3          0.000000       NO STAKE         NEVER STAKED      ONLY SWAPPED
# 4          0.000000       NO STAKE         NEVER STAKED  NO DEFI ACTIVITY
# ...             ...            ...                  ...               ...
# 8070       0.000000       NO STAKE         NEVER STAKED  NO DEFI ACTIVITY
# 8071       0.000000       NO STAKE         NEVER STAKED      ONLY SWAPPED
# 8072       0.000000       NO STAKE         NEVER STAKED  NO DEFI ACTIVITY
# 8073       0.000000       NO STAKE         NEVER STAKED      ONLY SWAPPED
# 8074       0.000000       NO STAKE         NEVER STAKED  NO DEFI ACTIVITY
#
# [8075 rows x 11 columns]

# %% [markdown]
# ## BACKUP
